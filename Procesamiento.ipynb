# %%
import zipfile
from urllib.request import urlopen

import io

url = "https://github.com/josemoragonzalez/DdA/blob/master/Subt.zip?raw=true"

zipfile.ZipFile(io.BytesIO(urlopen(url).read()))

# %%
    import pandas as pd 
    file = r'datos.csv'
    df = pd.read_csv(file, sep=';', low_memory = False)
    df.head(n=10)
# Out:
#           RUN                     Nombre Solicitante  \
# 0  96845720-9  EMPRESA CONSTRUCTORA HORIZONTE S.A.C.
# 1  96845720-9  EMPRESA CONSTRUCTORA HORIZONTE S.A.C.
# 2  96845720-9  EMPRESA CONSTRUCTORA HORIZONTE S.A.C.
# 3  96845720-9  EMPRESA CONSTRUCTORA HORIZONTE S.A.C.
# 4  96845720-9  EMPRESA CONSTRUCTORA HORIZONTE S.A.C.
# 5  96845720-9  EMPRESA CONSTRUCTORA HORIZONTE S.A.C.
# 6  96845720-9  EMPRESA CONSTRUCTORA HORIZONTE S.A.C.
# 7  96845720-9  EMPRESA CONSTRUCTORA HORIZONTE S.A.C.
# 8  96845720-9  EMPRESA CONSTRUCTORA HORIZONTE S.A.C.
# 9  96845720-9  EMPRESA CONSTRUCTORA HORIZONTE S.A.C.
#
#   Código de Expediente / Número Solicitud Tipo Solicitante    Región  \
# 0                          ND-0103-2352/1         Juridico  Tarapaca
# 1                          ND-0103-2354/1         Juridico  Tarapaca
# 2                          ND-0103-2855/1         Juridico  Tarapaca
# 3                          ND-0103-2852/1         Juridico  Tarapaca
# 4                          ND-0103-2856/1         Juridico  Tarapaca
# 5                          ND-0103-2850/1         Juridico  Tarapaca
# 6                          ND-0103-2851/1         Juridico  Tarapaca
# 7                          ND-0103-2853/1         Juridico  Tarapaca
# 8                          ND-0103-2353/1         Juridico  Tarapaca
# 9                          ND-0103-2854/1         Juridico  Tarapaca
#
#   Provincia        Comuna Naturaleza del Agua  \
# 0   Iquique  Pozo Almonte         Subterranea
# 1   Iquique  Pozo Almonte         Subterranea
# 2   Iquique  Pozo Almonte         Subterranea
# 3   Iquique  Pozo Almonte         Subterranea
# 4   Iquique  Pozo Almonte         Subterranea
# 5   Iquique  Pozo Almonte         Subterranea
# 6   Iquique  Pozo Almonte         Subterranea
# 7   Iquique  Pozo Almonte         Subterranea
# 8   Iquique  Pozo Almonte         Subterranea
# 9   Iquique  Pozo Almonte         Subterranea
#
#   Unidad de Resolución/ Oficio/ C.B.R.  \
# 0                          DGA Iquique
# 1                          DGA Iquique
# 2                          DGA Iquique
# 3                          DGA Iquique
# 4                          DGA Iquique
# 5                          DGA Iquique
# 6                          DGA Iquique
# 7                          DGA Iquique
# 8                          DGA Iquique
# 9                          DGA Iquique
#
#   Fecha de Resolución/ Envío al Juez/ Inscripción C.B.R.     ...       \
# 0                                           12/31/15         ...
# 1                                           12/31/15         ...
# 2                                           12/31/15         ...
# 3                                           12/31/15         ...
# 4                                           12/31/15         ...
# 5                                           12/31/15         ...
# 6                                           12/31/15         ...
# 7                                           12/31/15         ...
# 8                                           12/31/15         ...
# 9                                           12/31/15         ...
#
#   Unidad Distancia  Desnivel (M)               C.B.R. Fojas Nº C.B.R.     Año  \
# 0              NaN           0.0  C.B.R. Pozo Almonte   137       106  2016.0
# 1              NaN           0.0  C.B.R. Pozo Almonte   143       108  2016.0
# 2              NaN           0.0  C.B.R. Pozo Almonte   161       114  2016.0
# 3              NaN           0.0  C.B.R. Pozo Almonte   152       111  2016.0
# 4              NaN           0.0  C.B.R. Pozo Almonte   164       115  2016.0
# 5              NaN           0.0  C.B.R. Pozo Almonte   146       109  2016.0
# 6              NaN           0.0  C.B.R. Pozo Almonte   149       110  2016.0
# 7              NaN           0.0  C.B.R. Pozo Almonte   155       112  2016.0
# 8              NaN           0.0  C.B.R. Pozo Almonte   140       107  2016.0
# 9              NaN           0.0  C.B.R. Pozo Almonte   158       113  2016.0
#
#   Código Expediente Antiguo ¿Posee más de un Punto de Captación?  \
# 0                 4T(0-0-0)                                  NaN
# 1                 4T(0-0-0)                                  NaN
# 2                 4T(0-0-0)                                  NaN
# 3                 4T(0-0-0)                                  NaN
# 4                 4T(0-0-0)                                  NaN
# 5                 4T(0-0-0)                                  NaN
# 6                 4T(0-0-0)                                  NaN
# 7                 4T(0-0-0)                                  NaN
# 8                 4T(0-0-0)                                  NaN
# 9                 4T(0-0-0)                                  NaN
#
#   Nº Certificado/ Año         Tipo
# 0           4350/2017  Subterránea
# 1           4349/2017  Subterránea
# 2           3981/2017  Subterránea
# 3           4343/2017  Subterránea
# 4           3979/2017  Subterránea
# 5           4346/2017  Subterránea
# 6           4345/2017  Subterránea
# 7           4341/2017  Subterránea
# 8           4347/2017  Subterránea
# 9           3980/2017  Subterránea
#
# [10 rows x 64 columns]

# %%
print('hola')
# Out:
# hola
